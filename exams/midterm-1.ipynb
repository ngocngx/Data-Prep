# %%
import re
import numpy as np
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder, PowerTransformer, MinMaxScaler
pd.set_option('max_colwidth', 1000)

# %% [markdown]
# # Part 1

# %%
# read file
listings_df = pd.read_csv('data/midterm1-data/listings.csv')
listings_df.head()
# Out:
#        id                                                  address num_rooms  \
# 0  7332.0                  369 Barbara Square\nWhiteberg, MT 64361       __4
# 1     NaN  720 Stephen Garden Apt. 138\nSouth Haroldland, IA 96057         4
# 2  7023.0                         PSC 9388, Box 5285\nAPO AA 33803         3
# 3  2024.0         93507 Wells Brook Suite 898\nScottfort, IL 03739       (5)
# 4  6396.0         35641 Ashley Burg Suite 422\nScottview, SD 80942       __6
#
#   available
# 0         Y
# 1       yes
# 2         n
# 3         Y
# 4        no

# %%
# clean 'available' column
listings_df['available'] = listings_df['available'].replace(['y', 'Y'], 'yes')
listings_df['available'] = listings_df['available'].replace(['n', 'NO'], 'no')
listings_df['available'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
# remove non-difit form num_rooms
listings_df['num_rooms'] = listings_df['num_rooms'].str.extract('(\d+)')
listings_df['num_rooms'] = listings_df['num_rooms'].astype(int)
listings_df['num_rooms'].unique()
# Out:
# array([4, 3, 5, 6, 2, 1])

# %% [markdown]
# # Part 2

# %%
hackers_news_df = pd.read_csv('data/midterm1-data/hacker_news.csv')
hackers_news_df.head()
# Out:
#          id  \
# 0  12224879
# 1  11964716
# 2  11919867
# 3  10301696
# 4  10482257
#
#                                                                      title  \
# 0                                                Interactive Dynamic Video
# 1                  Florida DJs May Face Felony for April Fools' Water Joke
# 2                             Technology ventures: From Idea to Enterprise
# 3                        Note by Note: The Making of Steinway L1037 (2007)
# 4  Title II kills investment? Comcast and other ISPs are now spending more
#
#                                                                                                                url  \
# 0                                                                          http://www.interactivedynamicvideo.com/
# 1                           http://www.thewire.com/entertainment/2013/04/florida-djs-april-fools-water-joke/63798/
# 2                                 https://www.amazon.com/Technology-Ventures-Enterprise-Thomas-Byers/dp/0073523429
# 3                                                       http://www.nytimes.com/2007/11/07/movies/07stein.html?_r=0
# 4  http://arstechnica.com/business/2015/10/comcast-and-other-isps-boost-network-investment-despite-net-neutrality/
#
#    num_points  num_comments      author       created_at
# 0         386            52    ne0phyte   8/4/2016 11:52
# 1           2             1    vezycash  6/23/2016 22:20
# 2           3             1     hswarna   6/17/2016 0:01
# 3           8             2  walterbell   9/30/2015 4:12
# 4          53            22      Deinos  10/31/2015 9:48

# %%
# sum number of row mention sql in title 
hackers_news_df['title'].str.contains('sql', flags=re.IGNORECASE).sum()
# Out:
# 108

# %%
# create hn_sql contains only row mention sql in 'title'
hn_sql = hackers_news_df[hackers_news_df['title'].str.contains('sql', flags=re.IGNORECASE)]
hn_sql.head()
# Out:
#            id  \
# 9    11370829
# 142  10957172
# 221  11544342
# 394  10620525
# 419  10301554
#
#                                                                             title  \
# 9                       Crate raises $4M seed round for its next-gen SQL database
# 142                                          PostgreSQL: Linux VS Windows  part 2
# 221                                          MemSQL (YC W11) Raises $36M Series C
# 394                                                  The History of SQL Injection
# 419  Pentesterlab Tutorial  SQL injection to web admin console to getting a shell
#
#                                                                                                 url  \
# 9        http://techcrunch.com/2016/03/15/crate-raises-4m-seed-round-for-its-next-gen-sql-database/
# 142                             http://www.sqig.net/2016/01/postgresql-linux-vs-windows-part-2.html
# 221                                                  http://blog.memsql.com/memsql-raises-series-c/
# 394  http://motherboard.vice.com/read/the-history-of-sql-injection-the-hack-that-will-never-go-away
# 419                                           https://pentesterlab.com/exercises/from_sqli_to_shell
#
#      num_points  num_comments         author        created_at
# 9             3             1       hitekker   3/27/2016 18:08
# 142          16             3         based2    1/23/2016 4:21
# 221          74            14   ericfrenkiel   4/21/2016 18:32
# 394          38             9         kawera  11/24/2015 13:25
# 419           2             1  pentestercrab    9/30/2015 3:32

# %%
hn_sql['title'].str.extractall(r'(\w*SQL\w*)', flags=re.IGNORECASE)
# Out:
#                       0
#       match
# 9     0             SQL
# 142   0      PostgreSQL
# 221   0          MemSQL
# 394   0             SQL
# 419   0             SQL
# ...                 ...
# 19133 0      PostgreSQL
# 19580 0      PostgreSQL
# 19769 0             SQL
# 19802 0      PostgreSQL
# 19965 0             SQL
#
# [115 rows x 1 columns]

# %%
# extract sql flavor not case sensitive
hn_sql['flavor'] = hn_sql['title'].str.extract(r'(\w+SQL)', flags=re.IGNORECASE)
hn_sql['flavor'].unique()
# Out:
# /var/folders/mp/v9hjfv017hbfgx9mc09nw2y80000gn/T/ipykernel_42894/1081083759.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hn_sql['flavor'] = hn_sql['title'].str.extract(r'(\w+SQL)', flags=re.IGNORECASE)
# array([nan, 'PostgreSQL', 'MemSQL', 'NoSQL', 'MySQL', 'SparkSQL', 'nosql',
#        'mySql', 'CloudSQL'], dtype=object)

# %%
# convert flavour to lowercase
hn_sql['flavor'] = hn_sql['flavor'].str.lower()
hn_sql['flavor'].unique()
# Out:
# /var/folders/mp/v9hjfv017hbfgx9mc09nw2y80000gn/T/ipykernel_42894/222140313.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hn_sql['flavor'] = hn_sql['flavor'].str.lower()
# array([nan, 'postgresql', 'memsql', 'nosql', 'mysql', 'sparksql',
#        'cloudsql'], dtype=object)

# %%
# create pivot table index=flavour, value=num_comments, aggfunc=mean
hn_sql_pivot = pd.pivot_table(hn_sql, index='flavor', values='num_comments', aggfunc='mean')
hn_sql_pivot
# Out:
#             num_comments
# flavor
# cloudsql        5.000000
# memsql         14.000000
# mysql          12.230769
# nosql          14.529412
# postgresql     25.962963
# sparksql        1.000000

# %%
# extract protocol, domain, path
pattern = r"(?P<protocol>.+)://(?P<domain>[\w\-\.]+)(?P<path>.*)"
#catch those pattern in the url column and extract the domain
url_parts = hackers_news_df['url'].str.extract(pattern, flags=re.IGNORECASE)
url_parts.tail()
# Out:
#       protocol              domain  \
# 20094    https             puri.sm
# 20095    https          medium.com
# 20096     http  blog.darknedgy.net
# 20097    https          medium.com
# 20098    https          github.com
#
#                                                                         path
# 20094     /philosophy/how-purism-avoids-intels-active-management-technology/
# 20095  /@zreitano/the-yc-application-broken-down-and-translated-e4c0f5235081
# 20096                                              /technology/2016/01/01/0/
# 20097              /@benjiwheeler/how-product-hunt-really-works-d8fdcda1da74
# 20098                                                    /jmcarp/robobrowser

# %% [markdown]
# # Part 3

# %%
# extract title start with 'ask hn'
ask_hn = hackers_news_df[hackers_news_df['title'].str.startswith('Ask HN')]
ask_hn.head()
# Out:
#           id  \
# 6   12296411
# 16  10610020
# 21  11610310
# 29  12210105
# 30  10394168
#
#                                                                         title  \
# 6                                 Ask HN: How to improve my personal website?
# 16  Ask HN: Am I the only one outraged by Twitter shutting down share counts?
# 21                       Ask HN: Aby recent changes to CSS that broke mobile?
# 29                            Ask HN: Looking for Employee #3 How do I do it?
# 30     Ask HN: Someone offered to buy my browser extension from me. What now?
#
#     url  num_points  num_comments        author        created_at
# 6   NaN           2             6  ahmedbaracat    8/16/2016 9:55
# 16  NaN          28            29          tkfx  11/22/2015 13:43
# 21  NaN           1             1     polskibus    5/2/2016 10:14
# 29  NaN           1             3        sph130    8/2/2016 14:20
# 30  NaN          28            17      roykolak  10/15/2015 16:38

# %%
# extract title start with 'show hn'
show_hn = hackers_news_df[hackers_news_df['title'].str.startswith('Show HN')]
show_hn.head()
# Out:
#           id  \
# 12  10627194
# 38  10646440
# 45  11590768
# 83  12178806
# 96  10872799
#
#                                                                            title  \
# 12  Show HN: Wio Link  ESP8266 Based Web of Things Hardware Development Platform
# 38                                           Show HN: Something pointless I made
# 45                  Show HN: Shanhu.io, a programming playground powered by e8vm
# 83    Show HN: Webscope  Easy way for web developers to communicate with Clients
# 96                    Show HN: GeoScreenshot  Easily test Geo-IP based web pages
#
#                                url  num_points  num_comments      author  \
# 12            https://iot.seeed.cc          26            22     kfihihc
# 38         http://dn.ht/picklecat/         747           102     dhotson
# 45               https://shanhu.io           1             1       h8liu
# 83          http://webscopeapp.com           3             3   fastbrick
# 96  https://www.geoscreenshot.com/           1             9  kpsychwave
#
#           created_at
# 12  11/25/2015 14:03
# 38  11/29/2015 22:46
# 45   4/28/2016 18:05
# 83    7/28/2016 7:11
# 96    1/9/2016 20:45

# %%
# Do 'Ask HN' or 'Show HN' receive more comments on average?
print('Ask HN: ', ask_hn['num_comments'].mean(), 'Show HN: ', show_hn['num_comments'].mean())
ask_hn['num_comments'].mean() == show_hn['num_comments'].mean()
# Out:
# Ask HN:  14.044776119402986 Show HN:  10.324720068906116
# False

# %%
# Findings the number of ask post and comment by hour created
ask_hn['created_at'] = pd.to_datetime(ask_hn['created_at'])
ask_hn['hour_created'] = ask_hn['created_at'].dt.hour
ask_hn.head()
# Out:
# /var/folders/mp/v9hjfv017hbfgx9mc09nw2y80000gn/T/ipykernel_42894/2906153513.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ask_hn['created_at'] = pd.to_datetime(ask_hn['created_at'])
# /var/folders/mp/v9hjfv017hbfgx9mc09nw2y80000gn/T/ipykernel_42894/2906153513.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ask_hn['hour_created'] = ask_hn['created_at'].dt.hour
#           id  \
# 6   12296411
# 16  10610020
# 21  11610310
# 29  12210105
# 30  10394168
#
#                                                                         title  \
# 6                                 Ask HN: How to improve my personal website?
# 16  Ask HN: Am I the only one outraged by Twitter shutting down share counts?
# 21                       Ask HN: Aby recent changes to CSS that broke mobile?
# 29                            Ask HN: Looking for Employee #3 How do I do it?
# 30     Ask HN: Someone offered to buy my browser extension from me. What now?
#
#     url  num_points  num_comments        author          created_at  \
# 6   NaN           2             6  ahmedbaracat 2016-08-16 09:55:00
# 16  NaN          28            29          tkfx 2015-11-22 13:43:00
# 21  NaN           1             1     polskibus 2016-05-02 10:14:00
# 29  NaN           1             3        sph130 2016-08-02 14:20:00
# 30  NaN          28            17      roykolak 2015-10-15 16:38:00
#
#     hour_created
# 6              9
# 16            13
# 21            10
# 29            14
# 30            16

# %%
pivot_ask_hn = pd.pivot_table(ask_hn, index='hour_created', values='num_comments', aggfunc='sum')
pivot_ask_hn
# Out:
#               num_comments
# hour_created
# 0                      439
# 1                      683
# 2                     1381
# 3                      421
# 4                      337
# 5                      464
# 6                      397
# 7                      267
# 8                      492
# 9                      251
# 10                     793
# 11                     641
# 12                     687
# 13                    1253
# 14                    1416
# 15                    4477
# 16                    1814
# 17                    1146
# 18                    1430
# 19                    1188
# 20                    1722
# 21                    1745
# 22                     479
# 23                     543

# %% [markdown]
# # Part 4

# %%
revenue_df = pd.read_csv('data/midterm1-data/revenue.csv')
revenue_df
# Out:
#   CustomerID  Revenue        date
# 0      R1004       50  2021-12-01
# 1      W1002     5000  2021-09-01
# 2      R1002      150  2021-08-01
# 3      W1001     2000  2021-05-01
# 4      W1001     2200  2021-05-01
# 5      R1001      100  2021-04-01
# 6      R1001       30  2020-12-01
# 7      R1003      270  2020-09-01

# %%
# delete repeated id each month, keep row with larger revenue
revenue_df = revenue_df.sort_values(['date', 'Revenue'], ascending=False)
revenue_df = revenue_df.drop_duplicates(subset='CustomerID', keep='first')
revenue_df
# Out:
#   CustomerID  Revenue        date
# 0      R1004       50  2021-12-01
# 1      W1002     5000  2021-09-01
# 2      R1002      150  2021-08-01
# 4      W1001     2200  2021-05-01
# 5      R1001      100  2021-04-01
# 7      R1003      270  2020-09-01

# %%
# earliest revenue of each customer
earliest_revenue = revenue_df.sort_values(['CustomerID', 'date'], ascending=True)
earliest_revenue = earliest_revenue.drop_duplicates(subset='CustomerID', keep='first')
earliest_revenue
# Out:
#   CustomerID  Revenue        date
# 5      R1001      100  2021-04-01
# 2      R1002      150  2021-08-01
# 7      R1003      270  2020-09-01
# 0      R1004       50  2021-12-01
# 4      W1001     2200  2021-05-01
# 1      W1002     5000  2021-09-01

# %% [markdown]
# # Part 5

# %%
bank_df = pd.read_csv('data/midterm1-data/bank-additional-full.csv', sep=';')
bank_df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
bank_df['month'].unique()
# Out:
# array(['may', 'jun', 'jul', 'aug', 'oct', 'nov', 'dec', 'mar', 'apr',
#        'sep'], dtype=object)

# %%
# encode month jan: 0, feb: 1, ...
def map_month(x):
    month_dict = {'jan': 0, 'feb': 1, 'mar': 2, 'apr': 3, 'may': 4, 'jun': 5, 
                  'jul': 6, 'aug': 7, 'sep': 8, 'oct': 9, 'nov': 10, 'dec': 11}
    return month_dict[x]

bank_df['enc_month1'] = bank_df['month'].apply(lambda x: map_month(x))
bank_df['enc_month1'].unique()
# Out:
# array([ 4,  5,  6,  7,  9, 10, 11,  2,  3,  8])

# %%
# encode using encoder
encoder = OrdinalEncoder(categories=[['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']])
bank_df['enc_month2'] = encoder.fit_transform(np.array(bank_df['month']).reshape(-1, 1))
bank_df.head()
bank_df['enc_month2'].unique()
# Out:
# array([ 4.,  5.,  6.,  7.,  9., 10., 11.,  2.,  3.,  8.])

# %%
res = bank_df['enc_month1'] == bank_df['enc_month2']
res.value_counts()
# Out:
# True    41188
# Name: count, dtype: int64

# %%
transformer = PowerTransformer(method='yeo-johnson', standardize=False)
bank_df['duration'] = transformer.fit_transform(np.array(bank_df['duration']).reshape(-1, 1))
bank_df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  previous     poutcome  emp.var.rate  cons.price.idx  \
# 0   may         mon  ...         0  nonexistent           1.1          93.994
# 1   may         mon  ...         0  nonexistent           1.1          93.994
# 2   may         mon  ...         0  nonexistent           1.1          93.994
# 3   may         mon  ...         0  nonexistent           1.1          93.994
# 4   may         mon  ...         0  nonexistent           1.1          93.994
#
#   cons.conf.idx  euribor3m  nr.employed   y  enc_month1  enc_month2
# 0         -36.4      4.857       5191.0  no           4         4.0
# 1         -36.4      4.857       5191.0  no           4         4.0
# 2         -36.4      4.857       5191.0  no           4         4.0
# 3         -36.4      4.857       5191.0  no           4         4.0
# 4         -36.4      4.857       5191.0  no           4         4.0
#
# [5 rows x 23 columns]

# %%
scaler = MinMaxScaler()
bank_df['duration_T'] = scaler.fit_transform(np.array(bank_df['duration']).reshape(-1, 1))
bank_df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  ...     poutcome  emp.var.rate  \
# 0      telephone   may         mon  ...  nonexistent           1.1
# 1      telephone   may         mon  ...  nonexistent           1.1
# 2      telephone   may         mon  ...  nonexistent           1.1
# 3      telephone   may         mon  ...  nonexistent           1.1
# 4      telephone   may         mon  ...  nonexistent           1.1
# ...          ...   ...         ...  ...          ...           ...
# 41183   cellular   nov         fri  ...  nonexistent          -1.1
# 41184   cellular   nov         fri  ...  nonexistent          -1.1
# 41185   cellular   nov         fri  ...  nonexistent          -1.1
# 41186   cellular   nov         fri  ...  nonexistent          -1.1
# 41187   cellular   nov         fri  ...      failure          -1.1
#
#        cons.price.idx  cons.conf.idx euribor3m  nr.employed    y  enc_month1  \
# 0              93.994          -36.4     4.857       5191.0   no           4
# 1              93.994          -36.4     4.857       5191.0   no           4
# 2              93.994          -36.4     4.857       5191.0   no           4
# 3              93.994          -36.4     4.857       5191.0   no           4
# 4              93.994          -36.4     4.857       5191.0   no           4
# ...               ...            ...       ...          ...  ...         ...
# 41183          94.767          -50.8     1.028       4963.6  yes          10
# 41184          94.767          -50.8     1.028       4963.6   no          10
# 41185          94.767          -50.8     1.028       4963.6   no          10
# 41186          94.767          -50.8     1.028       4963.6  yes          10
# 41187          94.767          -50.8     1.028       4963.6   no          10
#
#        enc_month2  duration_T
# 0             4.0    0.530975
# 1             4.0    0.459655
# 2             4.0    0.512160
# 3             4.0    0.461292
# 4             4.0    0.552608
# ...           ...         ...
# 41183        10.0    0.564020
# 41184        10.0    0.582818
# 41185        10.0    0.489278
# 41186        10.0    0.602846
# 41187        10.0    0.519427
#
# [41188 rows x 24 columns]
